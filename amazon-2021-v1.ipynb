# %%
import pandas as pd
df=pd.read_csv('orders-shipments-2021-anony.csv')
df.head()
# Out:
#   Order Date     Website  Purchase Order Number Shipment Date Order Status  \
# 0   1/1/2021  Amazon.com                    NaN     1/10/2021      Shipped
# 1   1/2/2021  Amazon.com                    NaN      1/2/2021      Shipped
# 2   1/2/2021  Amazon.com                    NaN     1/10/2021      Shipped
# 3   1/3/2021  Amazon.com                    NaN      1/4/2021      Shipped
# 4   1/3/2021  Amazon.com                    NaN      1/5/2021      Shipped
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions Tax Charged  \
# 0  $23.99           $0.00                 $1.22            $3.60       $1.22
# 1  $74.99           $0.00                 $4.50            $0.00       $4.50
# 2  $15.49           $0.00                 $0.79            $2.32       $0.79
# 3   $9.49           $0.00                 $0.57            $0.00       $0.57
# 4  $29.89           $0.00                 $1.61            $2.99       $1.61
#
#   Total Charged Buyer Name  Group Name
# ...

# %%
df.shape
# Out:
# (481, 13)

# %%
df=df.fillna(0) #replaces NaN with 0
df.head()
# Out:
#   Order Date     Website  Purchase Order Number Shipment Date Order Status  \
# 0   1/1/2021  Amazon.com                    0.0     1/10/2021      Shipped
# 1   1/2/2021  Amazon.com                    0.0      1/2/2021      Shipped
# 2   1/2/2021  Amazon.com                    0.0     1/10/2021      Shipped
# 3   1/3/2021  Amazon.com                    0.0      1/4/2021      Shipped
# 4   1/3/2021  Amazon.com                    0.0      1/5/2021      Shipped
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions Tax Charged  \
# 0  $23.99           $0.00                 $1.22            $3.60       $1.22
# 1  $74.99           $0.00                 $4.50            $0.00       $4.50
# 2  $15.49           $0.00                 $0.79            $2.32       $0.79
# 3   $9.49           $0.00                 $0.57            $0.00       $0.57
# 4  $29.89           $0.00                 $1.61            $2.99       $1.61
#
#   Total Charged Buyer Name  Group Name
# ...

# %%
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
# Out:
# C:\Users\psfrago\AppData\Local\Temp\ipykernel_21616\2950817759.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)

# %%
df["Total Charged"].sum()
# Out:
# 14787.359999999999

# %%
df.head()
# Out:
#   Order Date     Website  Purchase Order Number Shipment Date Order Status  \
# 0   1/1/2021  Amazon.com                    0.0     1/10/2021      Shipped
# 1   1/2/2021  Amazon.com                    0.0      1/2/2021      Shipped
# 2   1/2/2021  Amazon.com                    0.0     1/10/2021      Shipped
# 3   1/3/2021  Amazon.com                    0.0      1/4/2021      Shipped
# 4   1/3/2021  Amazon.com                    0.0      1/5/2021      Shipped
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions Tax Charged  \
# 0  $23.99           $0.00                 $1.22            $3.60       $1.22
# 1  $74.99           $0.00                 $4.50            $0.00       $4.50
# 2  $15.49           $0.00                 $0.79            $2.32       $0.79
# 3   $9.49           $0.00                 $0.57            $0.00       $0.57
# 4  $29.89           $0.00                 $1.61            $2.99       $1.61
#
#    Total Charged Buyer Name  Group Name
# ...

# %%
df["Total Charged"].sum()
# Out:
# 14787.359999999999

# %%
df["Total Charged"].mean()
# Out:
# 30.74295218295218

# %%
df["Total Charged"].median()
# Out:
# 16.95

# %%
df["Total Charged"].max()
# Out:
# 402.79

# %%
df["Total Charged"].min()
# Out:
# 0.0

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# C:\Users\psfrago\AppData\Local\Temp\ipykernel_21616\148570183.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date     Website  Purchase Order Number Shipment Date Order Status  \
# 0   1/1/2021  Amazon.com                    0.0     1/10/2021      Shipped
# 1   1/2/2021  Amazon.com                    0.0      1/2/2021      Shipped
# 2   1/2/2021  Amazon.com                    0.0     1/10/2021      Shipped
# 3   1/3/2021  Amazon.com                    0.0      1/4/2021      Shipped
# 4   1/3/2021  Amazon.com                    0.0      1/5/2021      Shipped
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0  $23.99           $0.00                 $1.22            $3.60
# ...

# %%
df["Tax Charged"].sum()
# Out:
# 561.1

# %%
df["Tax Charged"].sum() / df["Total Charged"].sum()
# Out:
# 0.03794456887503923

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order Date     Website  Purchase Order Number Shipment Date Order Status  \
# 0 2021-01-01  Amazon.com                    0.0     1/10/2021      Shipped
# 1 2021-01-02  Amazon.com                    0.0      1/2/2021      Shipped
# 2 2021-01-02  Amazon.com                    0.0     1/10/2021      Shipped
# 3 2021-01-03  Amazon.com                    0.0      1/4/2021      Shipped
# 4 2021-01-03  Amazon.com                    0.0      1/5/2021      Shipped
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0  $23.99           $0.00                 $1.22            $3.60
# 1  $74.99           $0.00                 $4.50            $0.00
# 2  $15.49           $0.00                 $0.79            $2.32
# 3   $9.49           $0.00                 $0.57            $0.00
# 4  $29.89           $0.00                 $1.61            $2.99
#
#    Tax Charged  Total Charged Buyer Name  Group Name
# 0         1.22          21.61        PSF         0.0
# ...

# %%
df.plot.bar(x='Order Date', y='Total Charged', rot=90)
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
df.plot.bar(x='Order Date', y='Total Charged', rot=90, figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
daily_orders = df.groupby('Order Date').sum()["Total Charged"]
daily_orders.head()
# Out:
# Order Date
# 2021-01-01     21.61
# 2021-01-02     93.45
# 2021-01-03     68.19
# 2021-01-09     18.00
# 2021-01-10    167.33
# Name: Total Charged, dtype: float64

# %%
daily_orders.plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
daily_orders.plot.bar(figsize=(20, 10), color='#61D199')
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
df2=pd.read_csv('items-2021-anony.csv')
df2.head()
# Out:
#   Order Date                                              Title    Category  \
# 0   1/1/2021  Amazon Basics 100 Pack AAA High-Performance Al...     BATTERY
# 1   1/2/2021  5 in 1 Foot Spa/Bath Massager with Tea Tree Oi...    MASSAGER
# 2   1/2/2021  Amazon Basics 48 Pack AA High-Performance Alka...     BATTERY
# 3   1/3/2021  Kids Green Step Stool - Great for Potty Traini...  STEP_STOOL
# 4   1/3/2021  Falari 12-Pack Boy Toddler Kids Cotton Crew Socks       SOCKS
#
#     ASIN/ISBN  UNSPSC Code     Website Release Date Condition        Seller  \
# 0  B01B8R6V2E   26111702.0  Amazon.com          NaN       new    Amazon.com
# 1  B082291WHP   53131700.0  Amazon.com          NaN       new   Tip Top Toe
# 2  B00MNV8E0C   26111701.0  Amazon.com          NaN       new    Amazon.com
# 3  B01K7YBVUQ   56101800.0  Amazon.com          NaN       new  Steve's Mall
# 4  B075HPJB65   53102402.0  Amazon.com          NaN       new        Falari
#
# ...

# %%
df2["Item Total"] = df2["Item Total"].str.replace('$','').astype(float)
# Out:
# C:\Users\psfrago\AppData\Local\Temp\ipykernel_21616\3122082350.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2["Item Total"] = df2["Item Total"].str.replace('$','').astype(float)

# %%
df2.head(1)
# Out:
#   Order Date                                              Title Category  \
# 0   1/1/2021  Amazon Basics 100 Pack AAA High-Performance Al...  BATTERY
#
#     ASIN/ISBN  UNSPSC Code     Website Release Date Condition      Seller  \
# 0  B01B8R6V2E   26111702.0  Amazon.com          NaN       new  Amazon.com
#
#   Seller Credentials  ... Order Status Item Subtotal  Item Subtotal Tax  \
# 0                NaN  ...      Shipped       $23.99              $1.22
#
#    Item Total  Tax Exemption Applied Tax Exemption Type Exemption Opt-Out  \
# 0       25.21                  False                NaN             False
#
#   Buyer Name Currency Group Name
# 0        PSF      USD        NaN
#
# [1 rows x 27 columns]

# %%
categories = df2.groupby('Category').sum()["Item Total"]
categories
# Out:
# Category
# ABIS_BOOK                     224.29
# ABIS_DOWNLOADABLE_SOFTWARE      0.00
# ABIS_GIFT_CARD                195.00
# ADHESIVE_TAPES                 23.34
# ADVENT_CALENDAR                50.87
#                                ...
# WATCH                          20.96
# WATER                          19.89
# WATER_FLOTATION_DEVICE         29.46
# WRITING_INSTRUMENT             25.27
# YO_YO                          50.81
# Name: Item Total, Length: 238, dtype: float64

# %%
df2["Item Total"].sum()
# Out:
# 15415.48

# %%
df2
# Out:
#       Order Date                                              Title  \
# 0       1/1/2021  Amazon Basics 100 Pack AAA High-Performance Al...
# 1       1/2/2021  5 in 1 Foot Spa/Bath Massager with Tea Tree Oi...
# 2       1/2/2021  Amazon Basics 48 Pack AA High-Performance Alka...
# 3       1/3/2021  Kids Green Step Stool - Great for Potty Traini...
# 4       1/3/2021  Falari 12-Pack Boy Toddler Kids Cotton Crew Socks
# ...          ...                                                ...
# 1160  12/28/2021        Blistex Five Star Lip Protection, .15 Ounce
# 1161  12/30/2021  First Alert PRO5 Rechargeable Heavy Duty Plus ...
# 1162  12/31/2021  SCHOOL MASKPACK Teen/Adult XXL Reusable Wool F...
# 1163  12/31/2021  School MaskPack Crayola Kids Face Mask - 5 Reu...
# 1164  12/31/2021  School MaskPack Crayola Kids Face Mask - 5 Reu...
#
#                   Category   ASIN/ISBN  UNSPSC Code     Website Release Date  \
# ...

# %%
df2.shape
# Out:
# (1165, 27)

# %%
categories = df2.groupby('Category').sum()["Item Total"]
categories
# Out:
# Category
# ABIS_BOOK                     224.29
# ABIS_DOWNLOADABLE_SOFTWARE      0.00
# ABIS_GIFT_CARD                195.00
# ADHESIVE_TAPES                 23.34
# ADVENT_CALENDAR                50.87
#                                ...
# WATCH                          20.96
# WATER                          19.89
# WATER_FLOTATION_DEVICE         29.46
# WRITING_INSTRUMENT             25.27
# YO_YO                          50.81
# Name: Item Total, Length: 238, dtype: float64

# %%
df2.groupby('Category')

# %%
categories = df2.groupby('Category').sum()["Item Total"]
categories
# Out:
# Category
# ABIS_BOOK                     224.29
# ABIS_DOWNLOADABLE_SOFTWARE      0.00
# ABIS_GIFT_CARD                195.00
# ADHESIVE_TAPES                 23.34
# ADVENT_CALENDAR                50.87
#                                ...
# WATCH                          20.96
# WATER                          19.89
# WATER_FLOTATION_DEVICE         29.46
# WRITING_INSTRUMENT             25.27
# YO_YO                          50.81
# Name: Item Total, Length: 238, dtype: float64

# %%
df2.groupby(['Category'])['Item Total'].sum()
# Out:
# Category
# ABIS_BOOK                     224.29
# ABIS_DOWNLOADABLE_SOFTWARE      0.00
# ABIS_GIFT_CARD                195.00
# ADHESIVE_TAPES                 23.34
# ADVENT_CALENDAR                50.87
#                                ...
# WATCH                          20.96
# WATER                          19.89
# WATER_FLOTATION_DEVICE         29.46
# WRITING_INSTRUMENT             25.27
# YO_YO                          50.81
# Name: Item Total, Length: 238, dtype: float64

# %%
GBCAT=df2['Item Total'].groupby(df2['Category'])
GBCAT

# %%
len(list(df2['Item Total'].groupby(df2['Category'])))
# Out:
# 238

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1165 entries, 0 to 1164
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order Date               1165 non-null   object
#  1   Title                    1152 non-null   object
#  2   Category                 1152 non-null   object
#  3   ASIN/ISBN                1165 non-null   object
#  4   UNSPSC Code              1152 non-null   float64
#  5   Website                  1165 non-null   object
#  6   Release Date             28 non-null     object
#  7   Condition                1165 non-null   object
#  8   Seller                   1165 non-null   object
#  9   Seller Credentials       4 non-null      object
#  10  List Price Per Unit      1165 non-null   object
#  11  Purchase Price Per Unit  1165 non-null   object
#  12  Quantity                 1165 non-null   int64
#  13  Purchase Order Number    0 non-null      float64
# ...

# %%
df2['Category']=='nan'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1160    False
# 1161    False
# 1162    False
# 1163    False
# 1164    False
# Name: Category, Length: 1165, dtype: bool

# %%
(list(df2['Category'].unique()))
# Out:
# ['BATTERY',
#  'MASSAGER',
#  'STEP_STOOL',
#  'SOCKS',
#  'SHOES',
#  'SHIRT',
#  'FLASH_MEMORY',
#  'DAIRY_BASED_YOGURT',
#  'WATER',
#  'POULTRY',
#  'VEGETABLE',
#  'FRUIT',
#  'MEAT',
#  'DAIRY_BASED_ICE_CREAM',
#  'EGG',
#  'FOOD',
#  'DAIRY_BASED_DRINK',
#  'FISH',
#  'DAIRY_BASED_CREAM',
#  'SNACK_CHIP_AND_CRISP',
#  'JUICE_AND_JUICE_DRINK',
#  'CONDIMENT',
#  'YO_YO',
#  'TOY_FIGURE',
#  'ABIS_BOOK',
#  nan,
#  'UTILITY_SPONGE',
#  'MOUTHWASH',
#  'CLEANING_AGENT',
#  'TOY_BUILDING_BLOCK',
#  'PANTS',
#  'SCREEN_PROTECTOR',
#  'BREAD',
#  'PICKLE',
#  'GROCERY',
#  'BAKING_CHOCOLATE',
#  'RAZOR_BLADE_CARTRIDGE',
#  'TOOTH_CLEANING_AGENT',
#  'CHEWING_GUM',
#  'SKIN_FOUNDATION_CONCEALER',
#  'WRITING_INSTRUMENT',
#  'ENVELOPE',
#  'SKIN_CLEANING_AGENT',
#  'BAKING_PAPER',
#  'SEWING_TOOL_SET',
#  'REMOTE_CONTROL',
#  'COOKIE',
#  'SLIPPER',
#  'BAKING_MIX',
#  'HERB',
#  'CULINARY_SALT',
#  'DAIRY_BASED_CHEESE',
#  'FLAVORED_DRINK_CONCENTRATE',
#  'INPUT_PEN',
# ...

# %%
(list(df2['Item Total'].groupby(df2['Category'])))
# Out:
# [('ABIS_BOOK',
#   38       8.43
#   39       8.43
#   47      15.14
#   83      11.04
#   227     17.69
#   241      5.29
#   246      5.29
#   248      5.39
#   419      9.20
#   422      6.41
#   426      6.35
#   593      6.35
#   594      5.02
#   653     25.44
#   799     23.31
#   802     12.71
#   1035    10.59
#   1042    20.02
#   1045     8.47
#   1062     4.20
#   1117     9.52
#   Name: Item Total, dtype: float64),
#  ('ABIS_DOWNLOADABLE_SOFTWARE',
#   979    0.0
#   Name: Item Total, dtype: float64),
#  ('ABIS_GIFT_CARD',
#   547     25.0
#   582     25.0
#   990     20.0
#   1084    25.0
#   1085    50.0
#   1086    50.0
#   Name: Item Total, dtype: float64),
#  ('ADHESIVE_TAPES',
#   591     14.05
#   1132     9.29
#   Name: Item Total, dtype: float64),
#  ('ADVENT_CALENDAR',
#   987     25.44
#   1081    25.43
#   Name: Item Total, dtype: float64),
#  ('AMAZON_TABLET',
#   316    157.19
#   324    100.69
#   613    154.79
#   624    154.79
# ...

# %%
df2.describe()
df2.head()
# Out:
#   Order Date             Order ID  \
# 0   01/01/21  113-2862836-4969835
# 1   01/02/21  113-3647419-9257823
# 2   01/02/21  113-3663307-5643420
# 3   01/03/21  113-1321740-7777841
# 4   01/03/21  113-9532005-1239427
#
#                                                Title    Category   ASIN/ISBN  \
# 0  Amazon Basics 100 Pack AAA High-Performance Al...     BATTERY  B01B8R6V2E
# 1  5 in 1 Foot Spa/Bath Massager with Tea Tree Oi...    MASSAGER  B082291WHP
# 2  Amazon Basics 48 Pack AA High-Performance Alka...     BATTERY  B00MNV8E0C
# 3  Kids Green Step Stool - Great for Potty Traini...  STEP_STOOL  B01K7YBVUQ
# 4  Falari 12-Pack Boy Toddler Kids Cotton Crew Socks       SOCKS  B075HPJB65
#
#    UNSPSC Code     Website Release Date Condition        Seller  ...  \
# 0   26111702.0  Amazon.com          NaN       new    Amazon.com  ...
# 1   53131700.0  Amazon.com          NaN       new   Tip Top Toe  ...
# 2   26111701.0  Amazon.com          NaN       new    Amazon.com  ...
# ...

# %%
total_amount_spent = df2["Item Total"].sum()
print(f"Total amount spent: ${ total_amount_spent }")
# Out:
# Total amount spent: $15415.48

# %%
average_amount_spent_per_order = df2["Item Total"].mean()
print(f"Average amount spent per order: ${ round(average_amount_spent_per_order, 2) }")
# Out:
# Average amount spent per order: $13.23

# %%
df2.loc[df2["Item Total"] == df2["Item Total"].max()]
# Out:
#     Order Date             Order ID  \
# 911   09/28/21  111-0888521-0686628
#
#                                                  Title           Category  \
# 911  Mini PC i5-8279U 4 Cores Intel Processor(2.4GH...  PERSONAL_COMPUTER
#
#       ASIN/ISBN  UNSPSC Code     Website Release Date Condition     Seller  \
# 911  B08Z8CYXK8   43211516.0  Amazon.com          NaN       new  GMKtec-US
#
#      ... Carrier Name & Tracking Number Item Subtotal Item Subtotal Tax  \
# 911  ...       AMZN_US(TBA008732579904)       $429.99            $22.80
#
#      Item Total Tax Exemption Applied  Tax Exemption Type  Exemption Opt-Out  \
# 911      452.79                 False                 NaN              False
#
#     Buyer Name Currency Group Name
# 911        PSF      USD        NaN
#
# [1 rows x 36 columns]

# %%
df2.loc[df2["Item Total"] == df2["Item Total"].min()]
# Out:
#      Order Date             Order ID  \
# 33     01/10/21  113-7165860-2006662
# 61     01/18/21  113-3606657-0148248
# 75     01/18/21  113-3606657-0148248
# 95     02/02/21  112-1604299-5949052
# 139    02/14/21  113-4423607-7857043
# 141    02/14/21  113-4423607-7857043
# 157    02/14/21  113-4423607-7857043
# 285    03/15/21  113-9625592-8050668
# 415    04/17/21  113-9858376-5745062
# 434    05/01/21  113-3780991-2257810
# 435    05/01/21  113-3780991-2257810
# 449    05/01/21  113-3780991-2257810
# 453    05/01/21  113-3780991-2257810
# 456    05/01/21  113-3780991-2257810
# 496    05/15/21  113-7055120-4713819
# 497    05/15/21  113-7055120-4713819
# 523    05/29/21  113-7925626-9554603
# 533    05/29/21  113-7925626-9554603
# 557    06/06/21  113-6076491-1231429
# 605    06/14/21  114-6179192-6898649
# 610    06/14/21  114-6179192-6898649
# 657    07/01/21  111-4436865-8552259
# 666    07/10/21  111-3343145-7873804
# 715    07/25/21  111-7868039-5249804
# ...

# %%
df2.sort_values(ascending=False, by="Item Total").head(5)
# Out:
#      Order Date             Order ID  \
# 911    09/28/21  111-0888521-0686628
# 655    06/30/21  113-2943417-1044239
# 1150   12/25/21  114-8757870-9893803
# 316    03/22/21  113-8451001-6393827
# 624    06/22/21  111-4286990-5625056
#
#                                                   Title            Category  \
# 911   Mini PC i5-8279U 4 Cores Intel Processor(2.4GH...   PERSONAL_COMPUTER
# 655   Nintendo Switch - Animal Crossing: New Horizon...  VIDEO_GAME_CONSOLE
# 1150                              Amazon.com eGift Card           GIFT_CARD
# 316   Fire HD 10 Tablet (10.1" 1080p full HD display...       AMAZON_TABLET
# 624   Fire HD 10 tablet, 10.1", 1080p Full HD, 32 GB...       AMAZON_TABLET
#
#        ASIN/ISBN  UNSPSC Code     Website         Release Date Condition  \
# 911   B08Z8CYXK8   43211516.0  Amazon.com                  NaN       new
# 655   B084DDDNRP   43191601.0  Amazon.com  2020-03-13T00:00:01       new
# ...

# %%
fig, ax = plt.subplots(figsize=(15,6))
yoy_cost = df2.groupby(["Order Date"], as_index=False).sum()
sns.lineplot(x=yoy_cost["Order Date"], y=yoy_cost["Item Total"], color="grey")
plt.title("How much spending per year?")
plt.ylabel("Spending $");

# %%
fig, ax = plt.subplots(figsize=(15,6))
yoy_order_count = df2.groupby(["Order Date"], as_index=False).count()
sns.lineplot(x=yoy_order_count["Order Date"], y=yoy_order_count["Item Total"], color="Grey")
plt.title("How many orders per year?")
plt.ylabel("Count of Orders")
# Out:
# Text(0, 0.5, 'Count of Orders')
